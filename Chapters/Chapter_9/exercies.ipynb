# %%
classes = ["MATH 150", "PSYCH 111", "PSYCH 313", "PSYCH 412", "MATH 300", "MATH 404", "MATH 206", "ENG 100", "ENG 103", "ENG 201", "PSYCH 508", "ENG 220", "ENG 125", "ENG 124"]
upper = []
lower = []
split_classes = []

i = 0
for aclass in classes:
    split_classes.append(classes[i].split(' '))
    i += 1

print(split_classes)

# %%
classes = ["MATH 150", "PSYCH 111", "PSYCH 313", "PSYCH 412", "MATH 300", "MATH 404", "MATH 206", "ENG 100", "ENG 103", "ENG 201", "PSYCH 508", "ENG 220", "ENG 125", "ENG 124"]
upper = []
lower = []
split_classes = []
class_ints = []

i = 0
for aclass in classes:
    split_classes.append(classes[i].split(' '))
    i += 1

j = 0
for pair in split_classes:
    class_ints.append(split_classes[j][0]) #row j col 1?
    class_ints.append(int(split_classes[j][1])) #row j col 1?

    j += 1

md_list = [class_ints[0::2], class_ints[1::2]]

k = 0
n = 0
while k < len(md_list[0]):
    if md_list[0][k] == 'MATH':
        if md_list[1][k] >= 300:
            upper = upper +['MATH ' + str(md_list[1][k])]
            k += 1
        else:
            lower = lower + ['MATH ' + str(md_list[1][k])]
            k += 1
    elif md_list[0][k] == 'ENG':
        if md_list[1][k] >= 200:
            upper = upper + ['ENG ' + str(md_list[1][k])]
            k += 1
        else:
            lower = lower + ['ENG ' + str(md_list[1][k])]
            k += 1
    else:
        k += 1

print('Upper:', upper, 'Lower:', lower)

# %%
# reversing a string:
my_str = "this is a test"
r = my_str[::-1]
# print(r)
s = ''
index = len(my_str)
while index >= 0:
    index -= 1
    s = s + my_str[index]

print(s)
# Out:
# tset a si sihtt
