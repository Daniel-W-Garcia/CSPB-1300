# %%
tuples_lst = [('Beijing', 'China', 2008), ('London', 'England', 2012), ('Rio', 'Brazil', 2016, 'Current'), ('Tokyo', 'Japan', 2020, 'Future')]

country = []

for city, loc, yr in tuples_lst:
    country.append(loc)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 5
#       1 tuples_lst = [('Beijing', 'China', 2008), ('London', 'England', 2012), ('Rio', 'Brazil', 2016, 'Current'), ('Tokyo', 'Japan', 2020, 'Future')]
#       2
#       3 country = []
#       4
# ----> 5 for city, loc, yr in tuples_lst:
#       6     country.append(loc)
#
# ValueError: too many values to unpack (expected 3, got 4)
