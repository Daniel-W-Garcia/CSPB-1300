# %%
import string as s
alphabet = s.ascii_lowercase
cipher = 'clgubaebpxf'
r_cipher = cipher[:: -1]
w = cipher[:: 2]
rw = w[:: -1]
word = ''
word2 = ''
i = 0
j = 0

while i > - 13:
    i -= 1
    word = ''
    print(i)
    for c in r_cipher:
        c = alphabet.index(c) + i
        if c < 0:
            c += 25
        l = alphabet[c]
        word += l

    print('Reversed:', word)
while j < 13:
    j += 1
    word = ''
    print('J:', j)
    for c in cipher:
        c = alphabet.index(c) + j
        if c > 25:
            c = c % 26
        l = alphabet[c]
        word += l
    print('Normal:', word)

# %%
a = 20 / 22
print(a * 100)
# Out:
# 90.9090909090909
